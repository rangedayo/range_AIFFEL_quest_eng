# %% [markdown]
# <a href="https://colab.research.google.com/github/ParkHangah/AIFFEL_quest_eng/blob/master/Python/Py02/D010_Sub_Quest_%ED%81%B4%EB%A1%9C%EC%A0%80%EC%99%80_%EB%8D%B0%EC%BD%94%EB%A0%88%EC%9D%B4%EC%85%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [파이썬] 퀘스트: 클로저를 활용한 문제해결하기
#
# 난이도: ★★★☆☆
# 장르: nonlocal, 클로저, 데코레이터 활용
#
# ---

# %% [markdown]
# ## 문제 1. 최댓값과 최솟값 찾기

# %% [markdown]
# 조건:
# * 주어진 리스트의 최댓값과 최솟값을 반환하는 클로저 함수를 완성해 주세요.
#     * 주어진 숫자 리스트 numbers에 대해 find_min_max 함수를 호출하면 find_min과 find_max 함수를 얻을 수 있습니다.
#     * find_min() 함수를 호출하면 최솟값을, find_max()함수를 호출하면 최댓값을 반환합니다.
#     * 클로저를 사용하여 min_value와 max_value 변수를 외부에 노출하지 않고도 최솟값과 최대값을 찾을 수 있습니다.
#     * find_min_max 함수가 호출된 이후에도 find_min과 find_max 함수를 통해 min_value와 max_value 변수에 접근할 수 있습니다.
# * 주석으로 구현 내용이 써있는 부분을 코드로 채워주세요.
# ---
# 입력:
# ```python
# numbers = [10, 5, 8, 12, 3, 7]
# find_min, find_max = find_min_max(numbers)
#
# print("최솟값:", find_min())
# print("최댓값:", find_max())
# ```
# ---
# 출력:
# ```
# 3
# 12
# ```

# %% [markdown]
# ### Pair Programming 결과

# %%
def find_min_max(numbers):
    # min_value와 max_value 변수를 초기화
    # min_value는 양의 무한대(float('inf'))로 초기화하여 어떤 숫자보다도 큰 값으로 설정
    min_value = float('inf')
    # max_value는 음의 무한대(float('-inf'))로 초기화하여 어떤 숫자보다도 작은 값으로 설정
    max_value = float('-inf')

    def update_min_max(num):
      # 외부함수의 변수인 min_value, max_value 참조
      nonlocal min_value, max_value

      # 만약 num 값이 min_value보다 작다면 min_value를 num 값으로 변경
      if num < min_value:
        min_value = num

      # 만약 num 값이 max_value보다 크다면 max_value를 num 값으로 변경
      if num > max_value:
        max_value = num


    # numbers 리스트의 모든 값을 순환하며 최댓값과 최솟값 업데이트
    for num in numbers:
        update_min_max(num)

    # 최솟값을 반환하는 내부함수
    def get_min():
      return min_value

    # 최댓값을 반환하는 내부함수
    def get_max():
      return max_value

    # 외부함수는 내부함수(get_min()과 get_max())를 반환
    return get_min, get_max

# %%
numbers = [10, 5, 8, 12, 3, 7]
find_min, find_max = find_min_max(numbers)

print("최솟값:", find_min())  # 3
print("최댓값:", find_max())  # 12
# Out:
# 최솟값: 3
# 최댓값: 12

# %% [markdown]
# ## 문제 2. 함수의 호출 횟수를 세는 데코레이터

# %% [markdown]
# 지난 시간에 배운 데코레이터를 기억하시나요? 데코레이터도 내부함수를 반환하는 클로저를 활용한 문법입니다. 클로저를 활용하여 함수 호출 횟수를 출력하는 데코레이터를 만들어봅시다.
#
# 조건:
# * 함수가 실행될 때 마다 함수 이름과 실행 횟수를 출력하는 데코레이터 `counter` 만들기
#
# 힌트:
# * 데코레이터의 내부 함수(클로저)는 실행횟수를 기억하기 위해 외부 함수의 변수를 참조 해야 합니다
# * 함수의 이름은 `함수이름.__name__`으로 접근할 수 있습니다.
#
# ---
# 입력:
# ```python
# @counter
# def say_hello():
#     print("Hello Aiffel!")
#
# for i in range(5):
#     say_hello()
# ```
# ---
# 출력:
# ```
# Hello Aiffel!
# say_hello 실행횟수: 1
# Hello Aiffel!
# say_hello 실행횟수: 2
# Hello Aiffel!
# say_hello 실행횟수: 3
# Hello Aiffel!
# say_hello 실행횟수: 4
# Hello Aiffel!
# say_hello 실행횟수: 5
# ```

# %% [markdown]
# ### Pair Programming 결과

# %%
def counter(func):
    count = 0
    def wrapper(*args, **kwargs):
      nonlocal count
      count += 1
      result = func(*args, **kwargs)
      print(f"{func.__name__} 실행횟수: {count}")
      return result

    return wrapper

# %%
@counter
def say_hello():
    print("Hello Aiffel!")

for i in range(5):
    say_hello()
# Out:
# Hello Aiffel!
# say_hello 실행횟수: 1
# Hello Aiffel!
# say_hello 실행횟수: 2
# Hello Aiffel!
# say_hello 실행횟수: 3
# Hello Aiffel!
# say_hello 실행횟수: 4
# Hello Aiffel!
# say_hello 실행횟수: 5

# %% [markdown]
# ### Pair Programming 리뷰
#
# 내부 함수 클로저 부분에 몇가지 의문점이 있었음
#
# ```
# def wrapper(*args, **kwargs):          # 의문 Point 1
#       nonlocal count
#       count += 1
#       result = func(*args, **kwargs)   # 의문 Point 2
#       print(f"{func.__name__} 실행횟수: {count}")
#       return result                    # 의문 Point 3.
# ```
#
# #### **⁉ 의문 Point 1**. 매겨변수가 없는 데 굳이 적어줘야 할까?
#  ***arg**는 ***argument**의 줄임말로 여러개의 인자를 함수로 받을 때 사용
#  ****kwargs**는 ****keyword argument**의 줄임말로 {'키워드','특정값'} 형태의 키워드 인자를 함수로 받을 때 사용.
#  이번 퀘스트에서 데코레이션할 함수는 인자를 받지 않지만 인자를 받는 함수를 이용하는 경우에는 이런게 있으면 좋지 않을까? 생각
#  ➡ 한번 없애고 인수를 받는 함수를 데코레이션 해보자!
#
# #### **⁉ 의문 Point 2~3**. 굳이 기존 함수를 변수에 저장하고 return을 꼭 해워야 할까?
#   이번 꾸면주는 함수는 리턴값이 없지만,
#   리턴값이 있을 경우 문제가 있을 수도 있겠단 생각이 들음
#   ➡ 연시 한번 없애고 리턴값이 있는 함수를 데코레이션 해보자!

# %%
# 클로저 함수에 매개변수와 리턴을 모두 없앤 새로운 데코레이터 생성
def counter2(func):
    count = 0
    def wrapper():
      nonlocal count
      count += 1
      func()
      print(f"{func.__name__} 실행횟수: {count}")

    return wrapper

# %%
# 매개변수가 없고 리턴값도 없는 함수를 새로운 데코레이터로 꾸며주기
@counter2
def say_hello():
    print("Hello Aiffel!")

for i in range(5):
    say_hello()
# Out:
# Hello Aiffel!
# say_hello 실행횟수: 1
# Hello Aiffel!
# say_hello 실행횟수: 2
# Hello Aiffel!
# say_hello 실행횟수: 3
# Hello Aiffel!
# say_hello 실행횟수: 4
# Hello Aiffel!
# say_hello 실행횟수: 5

# %% [markdown]
# ##### Test1~2. 매개변수가 있는 함수 테스트

# %%
# 매개변수가 있는 함수
def say_hello2(name):
    print("Hello " + name + "!")

for i in range(5):
    say_hello2('Hangah')
# Out:
# Hello Hangah!
# Hello Hangah!
# Hello Hangah!
# Hello Hangah!
# Hello Hangah!

# %%
# Test1. 매개변수가 있는 함수를 새로운 데코레이터로 꾸며주기
@counter2
def say_hello2(name):
    print("Hello " + name + "!")

for i in range(5):
    say_hello2('Hangah')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1539068691.py in <cell line: 0>()
#       5
#       6 for i in range(5):
# ----> 7     say_hello2('Hangah')
#
# TypeError: counter2.<locals>.wrapper() takes 0 positional arguments but 1 was given

# %%
# Test2. 매개변수가 있는 함수를 기존 데코레이터로 꾸며주기
@counter
def say_hello2(name):
    print("Hello " + name + "!")

for i in range(5):
    say_hello2('Hangah')
# Out:
# Hello Hangah!
# say_hello2 실행횟수: 1
# Hello Hangah!
# say_hello2 실행횟수: 2
# Hello Hangah!
# say_hello2 실행횟수: 3
# Hello Hangah!
# say_hello2 실행횟수: 4
# Hello Hangah!
# say_hello2 실행횟수: 5

# %% [markdown]
# ##### Test3~4. 리턴값이 있는 함수 관련 테스트

# %%
# 리턴값이 있는 함수
def say_hello3():
    print = "Hello Aiffel!"
    return print

for i in range(5):
    print(say_hello3())
# Out:
# Hello Aiffel!
# Hello Aiffel!
# Hello Aiffel!
# Hello Aiffel!
# Hello Aiffel!

# %%
# Test3. 리턴값이 있는 함수를 새로운 데코레이터로 꾸며주기
@counter2
def say_hello3():
    print = "Hello Aiffel!"
    return print

for i in range(5):
    print(say_hello3())
# Out:
# say_hello3 실행횟수: 1
# None
# say_hello3 실행횟수: 2
# None
# say_hello3 실행횟수: 3
# None
# say_hello3 실행횟수: 4
# None
# say_hello3 실행횟수: 5
# None

# %%
# Test4. 리턴값이 있는 함수를 기존 데코레이터로 꾸며주기
@counter
def say_hello3():
    print = "Hello Aiffel!"
    return print

for i in range(5):
    print(say_hello3())
# Out:
# say_hello3 실행횟수: 1
# Hello Aiffel!
# say_hello3 실행횟수: 2
# Hello Aiffel!
# say_hello3 실행횟수: 3
# Hello Aiffel!
# say_hello3 실행횟수: 4
# Hello Aiffel!
# say_hello3 실행횟수: 5
# Hello Aiffel!
